# %% [markdown]
# > Conf inicial

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# crear un proyecto simple de prueba

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > commit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > Verificar

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > conectar a repositorio

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > subir proyecto

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > resumen

# %% [markdown]
# ![image.png](attachment:image.png)
